# %%
### Regularization
# This is a form of regression, that constraints/regularizes or shrinks the coefficient estimates towards zero.
# This technique discourages learning a more complex or flexible model, so as to avoid the risk of overfitting.

# %%
### Types: 
    # a. Lasso Regularization (L1)
    # b. Ridge Regularization (L2)

# %%
## a. Lasso Regularization (L1):
# Used in feature selection using a shrinkage method also referred to as penalized regression method.
# Lasso Regularization magnitude of coefficients can be **exactly** zero.
# Cost Function = Loss + lambda*sum(||w||)
# Note: Loss = sum of squared residual
      # lambda = penalty
      # w = slope of the curve = sum (|m1| + |m2| + ... + |mn|)

# %%
## b. Ridge Regularization (L2)
# Extension to linear regression that introduces a regularization term to reduce model complexity and help prevent overfitting.
# Ridge Regularization is working value/magnitude of coefficients is **almost equal** to zero.
# Cost Function = Loss + lambda*sum(||w||^2)
# Note: Loss = sum of squared residual
      # lambda = penalty
      # w = slope of the curve = sum (|m1| + |m2| + ... + |mn|)

# PROs: Reduces the computational complexity

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
dataset = pd.read_csv(r"../dataset/House Price India.csv")

# %%
dataset.head(3)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
# 2                       3  ...        1939                0       122004
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data=dataset.corr(), annot=True)
plt.show()

# %%
x = dataset.iloc[:, :-1]
x.head(3)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
#
#    condition of the house  ...  Area of the basement  Built Year  \
# 0                       5  ...                   280        1921
# 1                       5  ...                  1010        1909
# 2                       3  ...                     0        1939
#
#    Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# ...

# %%
y = dataset["Price"]
y.head(3)
# Out:
# 0    2380000
# 1    1400000
# 2    1200000
# Name: Price, dtype: int64

# %%
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x), columns=x.columns)
x.head(3)
# Out:
#          id      Date  number of bedrooms  number of bathrooms  living area  \
# 0 -1.713148 -1.685908            1.726515             0.481119     1.671691
# 1 -1.634590 -1.685908            0.661197             0.481119     0.885260
# 2 -1.576392 -1.685908            1.726515             0.805833     0.874487
#
#    lot area  number of floors  waterfront present  number of views  \
# 0 -0.159376          0.921180           -0.087863         4.916126
# 1 -0.292557         -0.004368           -0.087863        -0.304223
# 2 -0.148036         -0.004368           -0.087863        -0.304223
#
#    condition of the house  ...  Area of the basement  Built Year  \
# 0                2.363238  ...             -0.036740   -1.692844
# 1                2.363238  ...              1.590777   -2.099726
# 2               -0.648227  ...             -0.660993   -1.082522
#
#    Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
lr.score(x_test, y_test)
# Out:
# 0.7514192105693757

# %%
print(mean_squared_error(y_test, lr.predict(x_test)))
print(mean_absolute_error(y_test, lr.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test, lr.predict(x_test))))
# Out:
# 35029743918.94144
# 105542.36193843579
# 187162.34642401082

# %%
plt.figure(figsize=(20,7))
plt.bar(x.columns, lr.coef_)
plt.title("Linear Regression")
plt.xlabel("columns")
plt.ylabel("coef")
plt.show()

# %% [markdown]
# # Lasso - Feature Selection

# %%
l1 = Lasso(alpha=0.5)
l1.fit(x_train, y_train)
l1.score(x_test, y_test)
# Out:
# C:\Users\Gaurang\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.249e+13, tolerance: 1.563e+11
#   model = cd_fast.enet_coordinate_descent(
# 0.7514194765329543

# %%
print(mean_squared_error(y_test, l1.predict(x_test)))
print(mean_absolute_error(y_test, l1.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test, l1.predict(x_test))))
# Out:
# 35029706439.63311
# 105542.28788559261
# 187162.2462988546

# %%
plt.figure(figsize=(20,7))
plt.bar(x.columns, l1.coef_)
plt.title("Lasso")
plt.xlabel("columns")
plt.ylabel("coef")
plt.show()

# %% [markdown]
#  # Ridge

# %%
l2 = Ridge(alpha=10)
l2.fit(x_train, y_train)
l2.score(x_test, y_test)
# Out:
# 0.7514544956540136

# %%
print(mean_squared_error(y_test, l2.predict(x_test)))
print(mean_absolute_error(y_test, l2.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test, l2.predict(x_test))))
# Out:
# 35024771581.85193
# 105496.86037456243
# 187149.06246586418

# %%
plt.figure(figsize=(20,7))
plt.bar(x.columns, l2.coef_)
plt.title("Ridge")
plt.xlabel("columns")
plt.ylabel("coef")
plt.show()

# %%
df = pd.DataFrame({"col_name": x.columns, "LinearRegression": lr.coef_, "Lasso": l1.coef_, "Ridge": l2.coef_})

# %%
df
# Out:
#                                  col_name  LinearRegression          Lasso  \
# 0                                      id    -147083.192287 -147080.888698
# 1                                    Date        800.406136     799.844652
# 2                      number of bedrooms     -37175.768245  -37175.072593
# 3                     number of bathrooms      20159.188575   20155.406034
# 4                             living area      75851.884665  197373.486247
# 5                                lot area      -9178.983323   -9178.184946
# 6                        number of floors     -14078.706419  -14076.233276
# 7                      waterfront present      46802.085086   46801.836948
# 8                         number of views      25167.480252   25167.358467
# 9                  condition of the house       7496.288166    7496.038884
# 10                     grade of the house      61176.131436   61176.843422
# ...
